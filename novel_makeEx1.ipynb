# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)

# %%
import openai

openai.api_key = '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'

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def request_gpt_api(
    prompt: str,
    model: str = "gpt-3.5-turbo",
    max_token: int = 500,
    temperature: float = 0.8,
) -> str:
    response = openai.ChatCompletion.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        max_tokens=max_token,
        temperature=temperature,
    )

    return response.choices[0].message.content

# %%
def read_prompt_template(file_path: str) -> str:
    with open(file_path, "r") as f:
        prompt_template = f.read()

    return prompt_template

# %%
prompt_template = read_prompt_template('/content/drive/MyDrive/datas/prompt_text.txt')
prompt_template
# Out:
# '<등장 인물>\n        - James: 야망에 찬 사업가\n        - Kong: 생물학 연구소에서 일하는 유명한 박사, James 와 연인관계\n        - Bab: 질투 많은 경쟁사 사장\n</등장 인물>\n\n<뉴스 기사>\n기름값 하락 계속…휘발유 6.6원·경유 5.9원↓ 이번 주에도 국내 주유소 휘발유와 경유 판매 가격이 동반 하락했습니다.\n한국석유공사 유가정보시스템 오피넷에 따르면 6월 셋째주 전국 주유소 휘발유 평균 판매 가격은 전주보다 6.6원 하락한 리터당 1,575.8원을 기록했습니다.\n경유 판매 가격 역시 8.7원 내린 1,387.6원으로 집계됐습니다.\n휘발유 가격은 8주째, 경유 가격은 9주 연속 내림세입니다.\n대한석유협회 관계자는 "다음 주에도 휘발유·경유 가격은 하향 안정세를 보이겠지만, 그 다음 주부터는 특히 경유 가격이 반등할 가능성이 있다"고 전망했습니다.\n</뉴스 기사>\n\n<등장 인물> 과 <뉴스 기사> 를 소재로 새롭고 흥미진진한 스릴러 소설 아이디어를 한 문단으로 작성해줘'

# %%
request_gpt_api(prompt_template)
# Out:
# 'James는 야망에 찬 사업가로, 경쟁사 사장인 Bab에게 질투심을 품고 있다. 그러나 James는 Kong이라는 생물학 연구소에서 일하는 유명한 박사와 연인 관계에 있어, 그의 지원을 받고 있다. 어느 날, James는 뉴스 기사를 접하게 되는데, 그 기사에는 국내 주유소의 휘발유와 경유 판매 가격이 지속적으로 하락하고 있음을 알 수 있다. 이 기사는 James에게 한 가지 생각을 불러일으킨다. 그는 휘발유와 경유 가격이 계속해서 하락세를 보이는 동안, Bab의 경쟁사가 어떤 움직임을 보일지 예측하게 된다. James는 야망과 질투심에 불타오르며 스릴 넘치는 소설 아이디어를 갖게 되는데, 그 소설 속에서 James, Kong, Bab이 복잡하게 얽힌 인물관계와 이야기를 펼치며 대립과 소외, 암흑의 세계에서 사투를 벌이게 된다.'

# %%
request_gpt_api(prompt_teamplate, model='gpt-4', max_token=1000)
# Out:
# '<등장 인물>\n1. 데이빗 - 대학교 생화학과 교수, 파우스트 주스를 개발한 사람\n2. 알렉스 - 데이빗의 제자, 파우스트 주스를 본격적으로 사용하는 주인공\n3. 엘린 - 알렉스의 여자친구, 알렉스의 변화에 대한 걱정을 표현\n4. 잭슨 - 데이빗의 연구 동료, 파우스트 주스의 부작용에 대해 경고\n\n<뉴스 기사>\n최근에 공개된 \'파우스트 주스\'에 대한 논란이 확산되고 있다. 이 주스는 머리를 빠르게 돌리는 효과를 주는 것으로 알려져 있지만, 그 부작용에 대한 우려의 목소리도 커지고 있다. 사회의 이목을 집중시키고 있는 이 이슈에 대해 우리가 주목해야 할 것은 무엇인가?\n\n<스릴러 소설>\n\n제목: "파우스트의 선택"\n\n데이빗 교수는 \'파우스트 주스\'라는 놀라운 발명을 했다. 이 주스는 한 번마시면 단기간 동안 높은 지능을 발휘할 수 있게 한다. 그의 제자, 알렉스는 그 주스를 마시고 믿을 수 없을 만큼의 지적 능력을 얻게 된다. 그러나 그의 여자친구 엘린은 그의 변화에 대해 걱정한다.\n\n알렉스는 데이빗의 연구 동료인 잭슨으로부터 파우스트 주스의 부작용을 알게 된다. 그러나 그는 이미 그 주스에 중독되어 있었다. 그는 더 이상 그 주스 없이는 생각할 수 없게 된다. 그리고 그는 더 높은 지능을 갖기 위해 자신의 삶을 걸게 된다.\n\n기사가 공개되면서 사회는 파우스트 주스에 대해 알게 된다. 사람들은 그 주스를 마시면 높은 지능을 얻을 수 있지만 부작용으로 인해 끔찍한 결과를 겪게 된다는 것을 알게 된다. 그럼에도 불구하고 많은 사람들은 그 주스를 마시려고 한다. \n\n파우스트 주스는 시장에 출시되고, 사람들은 그것을 얻기 위해 목숨을 걸게 된다. 그리고 그들은 그것을 얻기 위해 범죄를 저지르기 시작한다. 그런데 과연 그 주스를 마신 사람들은 행복해질 수 있을까? 이것이 과연 진정한 지능인가? 이런 질문들이 사회를 뒤흔든다.\n\n\'파우스트의 선택\'은 그러한 질문들을 던지며 사회를 향해 물음표를 던진다. 그리고 그것은 그들이 얼마나 멀리 갈 수 있는지, 그리고 그들이 그것을 얻기 위해 얼마나 많은 것을 희생할 수 있는지를 보여준다.'

# %%
prompt_template = read_prompt_template('/content/drive/MyDrive/datas/prompt_template.txt')
prompt_template
# Out:
# '<등장 인물>\n{characters}\n</등장 인물>\n\n<뉴스 기사>\n{news_text}\n</뉴스 기사>\n\n<등장 인물> 과 <뉴스 기사> 를 소재로 새롭고 흥미진진한 {genre} 소설을 작성해줘'

# %%
def generate_novel(genre, characters, news_text) -> dict[str, str]:
    prompt_template = read_prompt_template('/content/drive/MyDrive/datas/prompt_template.txt')

    prompt = prompt_template.format(
        genre=genre,
        characters=characters,
        news_text=news_text,
    )

    return {"results": request_gpt_api(prompt)}

# %%
DEFAULT_GENRE = "Thriller"
DEFAULT_CHACRACTERS = [
    {"name": "James", "characteristics": "야망에 찬 사업가"},
    {"name": "Kong", "characteristics": "생물학 연구소에서 일하는 유명한 박사, James 와 연인관계"},
    {"name": "Bab", "characteristics": "질투 많은 경쟁사 사장"},
]
DEFAULT_NEWS_TEXT = """기름값 하락 계속…휘발유 6.6원·경유 5.9원↓ 이번 주에도 국내 주유소 휘발유와 경유 판매 가격이 동반 하락했습니다.
한국석유공사 유가정보시스템 오피넷에 따르면 6월 셋째주 전국 주유소 휘발유 평균 판매 가격은 전주보다 6.6원 하락한 리터당 1,575.8원을 기록했습니다.
경유 판매 가격 역시 8.7원 내린 1,387.6원으로 집계됐습니다.
휘발유 가격은 8주째, 경유 가격은 9주 연속 내림세입니다.
대한석유협회 관계자는 "다음 주에도 휘발유·경유 가격은 하향 안정세를 보이겠지만, 그 다음 주부터는 특히 경유 가격이 반등할 가능성이 있다"고 전망했습니다."""

# %%
generate_novel(DEFAULT_GENRE, DEFAULT_CHACRACTERS, DEFAULT_NEWS_TEXT)
# Out:
# {'results': '제임스(James)은 야망에 찬 사업가로, 경제 동향에 민감한 성격을 가지고 있습니다. 그는 현재 국내 주유소의 가격 하락에 주목하고 있으며, 이를 기회로 사업을 확장하려고 계획 중입니다.\n\n공(Kong)은 생물학 연구소에서 일하는 유명한 박사입니다. 제임스와는 연인 관계에 있으며, 그는 주유소 가격 하락의 배경에 대해 깊이 연구하고 있습니다. 제임스와 함께 주유소 시장의 동향을 파악하고, 그들의 관계와 업무를 조화시키면서 재미있는 이야기가 전개될 것입니다.\n\n밥(Bab)은 경쟁사의 사장으로 질투를 많이 품고 있는 인물입니다. 그는 제임스의 사업 확장 계획에 대해 경쟁심을 느끼고 있으며, 주유소 가격 하락에 대응하기 위해 적극적인 반응을 보일 것입니다. 그와 제임스, 그리고 공 사이의 갈등과 추격이 이 번 스릴러 소설의 장면을 더욱 흥미진진하게 만들 것입니다.\n\n스릴러 소설의 배경은 현실의 주유소 가격 하락과 경제 동향을 토대로 하되, 각 등장인물의 내면적 갈등, 욕망, 그리고 액션과 추격 등으로 긴밀하게 엮여 있을 것입니다. 주유소 사업의 성공'}
